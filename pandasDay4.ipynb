# %% [markdown]
# <a href="https://colab.research.google.com/github/RutujaBidkar/Pandas_Workplace/blob/main/pandasDay4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
department = pd.Series([ "IT", "HR", "IT", "Sales",
    "HR", "IT", "Sales"])
print(department.value_counts())
# Out:
# IT       3
# HR       2
# Sales    2
# Name: count, dtype: int64

# %%
cities = pd.Series(["Pune", "Mumbai", "Pune",
    "Delhi", "Mumbai", "Pune",
    "Delhi"
])
print(cities.value_counts())
# Out:
# Pune      3
# Mumbai    2
# Delhi     2
# Name: count, dtype: int64

# %%
marks = pd.Series([85, 90, None, 75, None])
print(marks.isna())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
print(marks.isnull())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
salary = pd.Series([25000, None, 40000, None, 55000, 60000])

# %%
print(salary.isna())
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
print(salary.isnull())
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
print(salary.notna())
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# dtype: bool

# %%
print(salary[salary.notna()])
# Out:
# 0    25000.0
# 2    40000.0
# 4    55000.0
# 5    60000.0
# dtype: float64

# %%
print(salary.notnull())
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# dtype: bool

# %%
age = pd.Series([25, None, 30, 28, None, 35])

# %%
print(salary.notnull())
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# dtype: bool

# %%
salary = pd.Series([25000, None, 40000, None, 55000])
print(salary.fillna(0))
# Out:
# 0    25000.0
# 1        0.0
# 2    40000.0
# 3        0.0
# 4    55000.0
# dtype: float64

# %%
print(salary.fillna(30000))
# Out:
# 0    25000.0
# 1    30000.0
# 2    40000.0
# 3    30000.0
# 4    55000.0
# dtype: float64

# %%
salary = salary.fillna(salary.mean())
print(salary)
# Out:
# 0    25000.0
# 1    40000.0
# 2    40000.0
# 3    40000.0
# 4    55000.0
# dtype: float64

# %%
marks = pd.Series([80, None, 70, None, 90])
print(marks.fillna(75))
# Out:
# 0    80.0
# 1    75.0
# 2    70.0
# 3    75.0
# 4    90.0
# dtype: float64

# %%
print(marks.dropna())
# Out:
# 0    80.0
# 2    70.0
# 4    90.0
# dtype: float64

# %%
marks = pd.Series([80, 90, 80, 70, 90, 60])
print(marks.duplicated())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
cities = pd.Series([
    "Pune", "Mumbai", "Pune",
    "Delhi", "Mumbai", "Pune"
])
print(cities.duplicated())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# dtype: bool

# %%
print(cities.drop_duplicates())
# Out:
# 0      Pune
# 1    Mumbai
# 3     Delhi
# dtype: object

# %%
products = pd.Series([
    "Laptop", "Mobile", "Laptop",
    "Tablet", "Mobile", "Mouse"
])
print(products.duplicated())
print(products.drop_duplicates())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool
# 0    Laptop
# 1    Mobile
# 3    Tablet
# 5     Mouse
# dtype: object

# %%
marks = pd.Series([80, 90, 70, 85])
result = marks[marks >75]
print(result)
# Out:
# 0    80
# 1    90
# 3    85
# dtype: int64
