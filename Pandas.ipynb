# %% [markdown]
# <a href="https://colab.research.google.com/github/RutujaBidkar/Pandas_Workplace/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
u = pd.Series([10,20,30,40,50])
print(u)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
Sales = pd.Series (
    [5000,6000,8000],
    index=["Jan","Feb","Mar"]
)
print(Sales)
# Out:
# Jan    5000
# Feb    6000
# Mar    8000
# dtype: int64

# %%
Details = pd.Series(

     [1233,34445,34555],
    index= ["Rutu","Rahul","Priya"]
)
#print(Details)
print(Details["Rahul"])
# Out:
# 34445

# %%
Emp_Details = pd.DataFrame({
  "Name":["Rahul","Priya","Preeti"],
  "Salary":[8523,7412,9632]
})
print(Emp_Details)
# Out:
#      Name  Salary
# 0   Rahul    8523
# 1   Priya    7412
# 2  Preeti    9632

# %%
Marks = pd.Series([10,20,30,40,50])
print(Marks[0])
# Out:
# 10

# %%
import pandas as pd

salary = pd.Series(
    [50000, 60000, 45000],
    index=["Rutuja", "Amit", "Priya"]
)

print(salary["Rutuja"])
print(salary["Priya"])
# Out:
# 50000
# 45000

# %%
Marks= pd.Series([80,85,95,74,74,89])
print(Marks.head())
# Out:
# 0    80
# 1    85
# 2    95
# 3    74
# 4    74
# dtype: int64

# %%
print(Marks.tail())
# Out:
# 1    85
# 2    95
# 3    74
# 4    74
# 5    89
# dtype: int64

# %%
print(Marks.sum())
# Out:
# 497

# %%
print(Marks.mean())
# Out:
# 82.83333333333333

# %%
print(Marks.max())
# Out:
# 95

# %%
print(Marks.min())
# Out:
# 74

# %%
print(Marks.count())
# Out:
# 6
